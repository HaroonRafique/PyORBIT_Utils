# %%
# %run /eos/project/l/liu/Toolbox/myToolbox.py

# %config InlineBackend.figure_format = 'retina'
# Out:
# Version 0.03. This is the latest version.
# Please help me to improve it reporting bugs to guido.sterbini@cern.ch.
# Your platform is Linux-3.10.0-693.11.6.el7.x86_64-x86_64-with-redhat-6.9-Carbon
# Your folder is /eos/user/a/ahuschau/Simulations/PS/optics_repository/iOMC/psmod/2018/output/twiss/QLB_insertion
# Your IP is 172.17.0.8
# 2018-08-20 21:37:22
# WARNING:cmmnbuild_dep_manager:JVM is already started

# %%
filename = '/eos/user/a/ahuschau/Simulations/PS/optics_repository/iOMC/psmod/2018/output/twiss/QLB_insertion/PS_without_QLB.twiss'
nominal = metaclass.twiss(filename)

filename = '/eos/user/a/ahuschau/Simulations/PS/optics_repository/iOMC/psmod/2018/output/twiss/QLB_insertion/PS_with_QLB.twiss'
QLB = metaclass.twiss(filename)

# %%
filename = '/eos/user/a/ahuschau/Simulations/PS/optics_repository/iOMC/psmod/2018/output/twiss/QLB_insertion/PS_with_QLB_at_0.2.twiss'
QLB2 = metaclass.twiss(filename)

# %%
filename = '/eos/user/a/ahuschau/Simulations/PS/optics_repository/iOMC/psmod/2018/output/twiss/QLB_insertion/PS_with_QLB_at_0.4.twiss'
QLB3 = metaclass.twiss(filename)

# %%
f, ax = plt.subplots(1, 2, figsize = (16,5), sharey = True)

ax[0].plot(nominal.S, nominal.BETX, label = 'LHC')
ax[0].plot(QLB.S, QLB.BETX, label = 'HI')

ax[0].axvline(nominal.S[1115], linestyle = '--', color = 'k')

ax[0].set_xlim(0, 2*np.pi*100)
ax[0].set_xlabel('s [m]')
ax[0].set_ylabel(r'$\beta_{x}$ [m]')
ax[0].legend()

ax[1].plot(nominal.S, nominal.BETX, label = 'LHC')
ax[1].plot(QLB.S, QLB.BETX, label = 'HI')

ax[1].axvline(nominal.S[1115], linestyle = '--', color = 'k')
ax[1].axvline(nominal.S[1140], linestyle = '--', color = 'k')

ax[1].set_xlim(200, 300)
ax[1].set_xlabel('s [m]')
ax[1].legend()

# %%
f, ax = plt.subplots(1, 2, figsize = (16,5), sharey = True)

ax[0].plot(QLB.S, QLB.BETX, label = 'LHC')
ax[0].plot(QLB2.S, QLB2.BETX, label = 'HI')

ax[0].axvline(nominal.S[1115], linestyle = '--', color = 'k')

ax[0].set_xlim(0, 2*np.pi*100)
ax[0].set_xlabel('s [m]')
ax[0].set_ylabel(r'$\beta_{x}$ [m]')
ax[0].legend()

ax[1].plot(QLB.S, QLB.BETX, label = 'LHC')
ax[1].plot(QLB2.S, QLB2.BETX, label = 'HI')

ax[1].axvline(nominal.S[1115], linestyle = '--', color = 'k')
ax[1].axvline(nominal.S[1140], linestyle = '--', color = 'k')

ax[1].set_xlim(200, 300)
ax[1].set_xlabel('s [m]')
ax[1].legend()

# %%
f, ax = plt.subplots(1, 2, figsize = (16,5), sharey = True)

ax[0].plot(QLB.S, QLB.BETX, label = 'LHC')
ax[0].plot(QLB3.S, QLB3.BETX, label = 'HI')

ax[0].axvline(nominal.S[1115], linestyle = '--', color = 'k')

ax[0].set_xlim(0, 2*np.pi*100)
ax[0].set_xlabel('s [m]')
ax[0].set_ylabel(r'$\beta_{x}$ [m]')
ax[0].legend()

ax[1].plot(QLB.S, QLB.BETX, label = 'LHC')
ax[1].plot(QLB3.S, QLB3.BETX, label = 'HI')

ax[1].axvline(nominal.S[1115], linestyle = '--', color = 'k')
ax[1].axvline(nominal.S[1140], linestyle = '--', color = 'k')

ax[1].set_xlim(200, 300)
ax[1].set_xlabel('s [m]')
ax[1].legend()
